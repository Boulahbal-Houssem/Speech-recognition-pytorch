# %% [markdown]
# <b>Mounting Google Drive in Google Colab

# %%
from google.colab import drive
drive.mount('/mydrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /mydrive

# %% [markdown]
# <b>Navigating to project directory

# %%
cd /
# Out:
# /

# %%
cd mydrive/My Drive/Colab Notebooks/Deep learning (Traitement de Paroles)/Speech-Commands-Recognition
# Out:
# /mydrive/My Drive/Colab Notebooks/Deep learning (Traitement de Paroles)/Speech-Commands-Recognition

# %% [markdown]
# <b>Installing required packages

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl 
# !pip3 install torchvision
# !pip3 install librosa
# !pip3 install Pillow==4.0.0
# !pip3 install PIL
# !pip3 install image
import PIL.Image
# Out:
# ...
#     100% |████████████████████████████████| 483.0MB 54.6MB/s
# fastai 1.0.46 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# fastai 1.0.46 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...
#   Found existing installation: torch 1.0.1.post2
#     Uninstalling torch-1.0.1.post2:
#       Successfully uninstalled torch-1.0.1.post2
# ...
#     100% |████████████████████████████████| 5.6MB 5.9MB/s
# ...
# torchvision 0.2.2.post3 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# imgaug 0.2.8 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# fastai 1.0.46 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# fastai 1.0.46 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.8 which is incompatible.
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# <b>Importing required packages from Project

# %%
import torch
from torchvision import models, datasets, transforms
import librosa
from utils import util
import IPython.display as ipd
import os
import matplotlib.pyplot as plt

# %%
cd ../../..
# Out:
# /mydrive/My Drive/Colab Notebooks/Deep learning (Traitement de Paroles)/Speech-Commands-Recognition

# %%
cd PrepareData/dataset/go
# Out:
# /mydrive/My Drive/Colab Notebooks/Deep learning (Traitement de Paroles)/Speech-Commands-Recognition/PrepareData/dataset/go

# %%
ls
# Out:
# 004ae714_nohash_0.wav  5828dfa2_nohash_0.wav  b433332a_nohash_0.wav
# 004ae714_nohash_1.wav  5828dfa2_nohash_1.wav  b433332a_nohash_1.wav
# 00b01445_nohash_0.wav  589bce2c_nohash_0.wav  b43c8f2f_nohash_0.wav
# 00f0204f_nohash_0.wav  589bce2c_nohash_1.wav  b43de700_nohash_0.wav
# 00f0204f_nohash_1.wav  590750e8_nohash_0.wav  b43de700_nohash_1.wav
# 012c8314_nohash_0.wav  590750e8_nohash_1.wav  b43de700_nohash_2.wav
# 012c8314_nohash_1.wav  590750e8_nohash_2.wav  b4604db4_nohash_0.wav
# 012c8314_nohash_2.wav  591d32f3_nohash_0.wav  b4604db4_nohash_1.wav
# 0132a06d_nohash_0.wav  59fe87e6_nohash_0.wav  b46e8153_nohash_0.wav
# 0132a06d_nohash_1.wav  59fe87e6_nohash_1.wav  b487da60_nohash_0.wav
# 0132a06d_nohash_2.wav  5a0bc987_nohash_0.wav  b487da60_nohash_1.wav
# 0132a06d_nohash_3.wav  5a0bc987_nohash_1.wav  b49caed3_nohash_0.wav
# 0132a06d_nohash_4.wav  5a3712c9_nohash_0.wav  b49caed3_nohash_1.wav
# 0137b3f4_nohash_0.wav  5a9f7324_nohash_0.wav  b49caed3_nohash_2.wav
# ...

# %%
ipd.Audio('PrepareData/dataset/go/b4604db4_nohash_0.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
util.demo('saved/2019-02-22_21:02:41/cycle_3')
# Out:
# Generating Spectograms
# Performing prediction
# Prediction for demo.wav:go
